# %%
from IPython.display import display, HTML

display(HTML('''
<style>
    /* Globale Stildefinitionen für RISE */
     /* Schriftgröße für den Code in Codezellen erhöhen */
    .reveal .input_area p {
        font-size: 3.5em !important; /* Ändert die Schriftgröße für den Code */
    }
    .reveal .output_area {
        font-size: 3.5em !important; /* Ändert die Schriftgröße für den Output */
    }
    /* Optional: Padding und Margins anpassen */
    .reveal input_area, .reveal output_area {
        padding: 10px; /* Fügt mehr Innenabstand hinzu */
        margin: 10px; /* Fügt mehr Außenabstand hinzu */
    }
    .reveal p {
    font-size: 2em; /* Ändert die Schriftgröße für Fließtext */
}
 /* Globale Stildefinitionen für RISE */
    .reveal ptable {
        width: 100%; /* Ändert die Breite der Tabelle auf 100% */
        font-size: 2em v!important; /* Ändert die Schriftgröße innerhalb der Tabelle */
    }
    .reveal th, .reveal td {
        padding: 10px; /* Fügt Innenabstand zu den Zellen hinzu */
        text-align: left; /* Ausrichtung des Textes in den Zellen */
    }
</style>
'''))
# Out:
# <style>
#     /* Globale Stildefinitionen für RISE */
#      /* Schriftgröße für den Code in Codezellen erhöhen */
#     .reveal .input_area p {
#         font-size: 3.5em !important; /* Ändert die Schriftgröße für den Code */
#     }
#     .reveal .output_area {
#         font-size: 3.5em !important; /* Ändert die Schriftgröße für den Output */
#     }
#     /* Optional: Padding und Margins anpassen */
#     .reveal input_area, .reveal output_area {
#         padding: 10px; /* Fügt mehr Innenabstand hinzu */
#         margin: 10px; /* Fügt mehr Außenabstand hinzu */
#     }
#     .reveal p {
#     font-size: 2em; /* Ändert die Schriftgröße für Fließtext */
# }
#  /* Globale Stildefinitionen für RISE */
#     .reveal ptable {
#         width: 100%; /* Ändert die Breite der Tabelle auf 100% */
#         font-size: 2em v!important; /* Ändert die Schriftgröße innerhalb der Tabelle */
#     }
#     .reveal th, .reveal td {
# ...

# %% [markdown]
# <center>
# <img src="figures/python_logo.png" alt="Python Logo" width="1000"/>
# </center>
#
# # **Einführung in Datenauswertung mit Python**

# %% [markdown]
# ### Vorlesung Theoretische Chemie (WiSe 2024/2025)
#
# Jannis Kockläuner
#
# jannis.kocklaeuner@tu-dresden.de

# %% [markdown]
# # Ablauf
# ## 13.11 - Grundlagen von Python
# - Warum Python?
# - Wie funktioniert Python?
# - Was ist ein Programm?
# - Datenstrukturen
# - Kontrollstrukturen
#
# ## 14.11 - Funktionen und Module
# - Was sind Funktionen? Wie definiert man eigene Funktionen?
# - Funktionen richtig nutzen
# - Datenauswertung: **Numpy (Numerisches Python)**
# - Daten laden
# - Daten auswerten mit mathematischen Funktionen
#
# ## 20.11 - Daten Visualisieren
# - Einführung in das `Matplotlib` Modul
# - Erstellen von Grafiken in Python
#
# ## 11.12 - Projekteinführung
# - Vorstellung eines Abschlussprojekts **(Jan)**
# - Übung: Daten auswerten und visualisieren

# %% [markdown]
# # Motivation: Automatische Visualisierung
# ### Beispiel: IR-Spektrum
# <center>
# <img src="figures/tex0_3-1.png" alt="Datenauswertung" width="1200"/>
# </center>
#
# ### Vorteile des Programmierens für Abbildungen
# - **Reproduzierbar:** Code bleibt bestehen - der Aufwand weitere Abbildungen im selben Stil zu erzeugen beträgt praktisch 0.
# - **Wiederverwendbar:** Kleine Änderung lassen sich leicht und schnell durch Anpassungen an bestehendem Code durchführen - Copy und Paste funktioniert oft.
# - **Flexibel:** Grafiken können beliebig verändert und angepasst werden. Das beinhaltet das Erstellen von mehreren Grafiken, das Hinzufügen weiterer Objekte (Pfeile, Linien, Kreise, ...) und viel mehr.
# - **Hohe Qualität:** Konventionen wie Schrifgröße, Achsenbeschrifung etc. können leicht automatisiert werden und ermöglichen es schnell sehr hochwertige Grafiken zu erstellen.

# %% [markdown]
# # Motivation: Automatische Datenauswertung
#
# ### Auswertung von vielen, ähnlichen Daten: Beispiel IR-Spektrum
#
# <center>
# <img src="figures/tex0_33-1.png" alt="Datenauswertung" width="1200"/>
# </center>
#
# ### Vorteile des Programmierens für Datenauswertung
# - **Reproduzierbar:** Code bleibt bestehen - die Analyse bleibt nachvollziehbar und wiederholbar, auch wenn die Daten sich ändern.
# - **Automatisierung:** Die selbe Analyse lässt sich mit nahezu beliebig vielen Daten durchführen - ohne nennenswerten zusätzlichen Arbeitsaufwand.
# - **Auswertung:** Die Datenauswertung kann beliebig komplex sein - eine "general purpose" Programmiersprache kann so ziemlich jede Art von Algorithmus ausführen
# - **Zeitaufwand:** Nach der Implementierung laufen Skripte gewöhnlich in **Sekunden** - selbst wenn sie hunderte von Dateien auswerten.

# %% [markdown]
# # Motivation: Animationen
#
# **Animationen** können sehr hilfreich sein um komplexe Prozesse abzubilden. Das Programmieren bietet den Vorteil das sowohl die Daten als auch die Animation selber in einem Schritt erzeugt werden können.
#
# <table>
#   <tr>
#     <td>
#         <strong style="display: block; text-align: center; margin-bottom: 5px;">Diffusion Monte Carlo Simulation eines harmonischen Oszillators</strong>
#       <figure>
#         <img src="figures/harmon_dmc.gif" width="1000"/>
#       </figure>
#     </td>
#     <td>
#         <strong style="display: block; text-align: center; margin-bottom: 5px;">Simulation der Bewegung der Erde um die Sonne</strong>
#       <figure>
#         <img src="figures/sun_earth.gif" alt="Datenauswertung" width="1000"/>
#       </figure>
#     </td>
#   </tr>
# </table>

# %% [markdown]
# # Motivation: Physikalisches Verständnis von Vorgängen
#
# **Physik und Chemie sind experimentelle Wissenschaften** - oft ist es einfacher zu sehen was passiert als einfach nur eine Gleichung anzuschauen. Durch **Simulationen** kann man oft intuitiver verstehen was passiert.
#
# <table>
#   <tr>
#     <td>
#         <strong style="display: block; text-align: center; margin-bottom: 5px;">Atomorbital des Wasserstoff Atoms</strong>
#       <figure>
#         <img src="figures/dz-1.png" width="1000"/>
#       </figure>
#     </td>
#     <td>
#         <strong style="display: block; text-align: center; margin-bottom: 5px;">Quantenmechanisches Doppelmuldenpotential</strong>
#       <figure>
#         <img src="figures/doppelmulde.png" width="1000"/>
#       </figure>
#     </td>
#   </tr>
# </table>

# %% [markdown]
# # Beispiel: Quantenmechanischer Tunneleffekt
#
# <center>
# <img src="figures/doppelmulde.png" width="1000"/>
# </center>
#
# ### 1D - Doppelmuldenpotential:
# **Hamiltonian:** $\hat{H} = \frac{\hat{p}^2}{2} + x^4 - x^2 - 0.05 * x$
# - **Klassische Zeitwentwicklung:** Teilchen fällt in eine Mulde wenn die kinetische Energie nicht reicht um die Barriere zu überwinden
# - **Quantenmechanische Zeitentwicklung:** Das Teilchen kann tunneln und hat in beiden Mulden eine nicht verschwindende Wahrscheinlichkeit

# %% [markdown]
# # Warum Python?
# ### Ranking der beliebtesten Programmiersprachen
# <center>
# <img src="figures/python_ranking.jpeg" alt="" width="1000"/>
# </center>
#
# Quelle: [Hier](https://de.statista.com/infografik/16544/anteile-der-populaersten-programmiersprachen-weltweit/)
#
# - **Vielseitigkeit:** Python kann für eine Vielzahl von Anwendungen verwendet werden, darunter Webentwicklung, Datenanalyse, maschinelles Lernen, wissenschaftliche Berechnungen, Systemskripting, Automatisierung und vieles mehr.
# -  **Wir beschränken uns auf eine spezielle Anwendung (Datenverarbeitung) und nutzen dafür nur wenige, grundlegende Funktionalitäten!** Notwendigerweise werden dadurch viele Themen nur oberflächlich und/oder unvollständig behandelt.

# %% [markdown]
# # Nützliche Resourcen
# ### Online Resourcen
# - **Google**
# - **Stack Overflow**
# - Python Dokumentation
# - Youtube Tutorials
#  <table><tr>
# <td> <img src="figures/Stack_Overflow_icon.svg" alt="Datenauswertung" width="400"/>
# <td> <img src="figures/python_logo.png" alt="Drawing" width=400/> </td>
# <td> <img src="figures/youtube.webp" alt="Drawing" width=400/> </td>
# </tr></table>
#
# ### Coding Hilfen
# - **Syntax Highlighting** - Findet Syntax Fehler im Code und ist Standard bei IDE's wie Pycharm
# - **AI Assistenten** - ChatGPT & Co können guten Code schreiben - wenn **genau beschrieben wird was gebraucht wird**

# %% [markdown]
# # Warum Python?
# - **Einfach und leicht zu lesen:** Der Code lässt sich oft intuitiv verstehen, was die Sprache ideal für Einsteiger macht.
# - Funktionen und Operatoren orientieren sich an englischen Begriffen
# - Python verwendet Einrückungen um Codeblöcke zu kennzeichnen. Das erleichtert die Strukturierung und Lesbarkeit.

# %%
# Beispiel: Lesbarkeit
my_number = 9
if my_number >= 10:
    print(my_number)
else:
    print("Die Zahl ist kleiner als 10!")

# %% [markdown]
# # Warum Python?
# - **Interaktiv und interpretierbar:** Python ist eine interpretierte Sprache, was bedeutet, dass der Code direkt Zeile für Zeile ausgeführt wird. Das macht es einfach, Code direkt auszuprobieren und zu testen.
# - Der Code wird von einem Python Interpreter von oben nach unten gelesen und ausgeführt
#
# <center>
# <img src="figures/compiler.webp" alt="" width="1000"/>
# </center>

# %% [markdown]
# Quelle: [Hier](https://medium.com/@kaushik.k/internal-working-of-python-415572929e7a)

# %% [markdown]
# # Fehlermeldungen: Computer sind dumm, aber Fehlermeldungen sind nützlich!
# Wenn der Code nicht lesbar für den Compiler (Python) ist, wird eine Fehlermeldung produziert. **Fehlermeldungen in Python sind (meistens) sehr nützlich!** Sie enthalten wichtige Informationen  um den Fehler zu finden und zu verbessern:
# - Fehlercode (NameError, IndexError, SyntaxError, ...)
# - Wo tritt der Fehler auf?
# - Um was für eine Art von Fehler handelt es sich konkret?
# Fehlermeldungen sind essentiell um Fehlfunktionen des Programms zu verhindern - ein Programm sollte nicht funktionieren wenn nicht eindeutig ist was es tun soll.

# %% [markdown]
# # Warum Python?
# - **Module und Bibliotheken:** Python verfügt über eine Vielzahl von Bibliotheken und Frameworks, die die Entwicklung erheblich erleichtern. Beispiele sind:
#
#    - NumPy, Pandas, Matplotlib für Datenwissenschaft und -analyse
#    - Django, Flask für Webentwicklung
#    - TensorFlow, PyTorch für maschinelles Lernen
#
# -  Für komplexe Aufgaben ist es oft **einfacher und sinnvoller** nach dem passenden Paket zu suchen anstatt selbst sämtliche Funktionalitäten zu programmieren.
# <center>
# <img src="figures/python_modules.jpg" alt="Google Colab" width="1000"/>
# </center>
#
# Quelle: [Hier](https://www.linkedin.com/pulse/top-10-python-libraries-pranshu-jaryal)

# %% [markdown]
# # Module und Bibliotheken: Beispiel Sinusfunktion
# Definition der Sinusfunktion:
# $Sin(x) \approx x - \frac{x^3}{3!} + \frac{x^5}{5!} - \dots$

# %%
# Beispiel: Sinusfunktion
def sinus(x, n):
# Taylornäherung der Sinusfunktion
# sin(x) = x - x^3/3! + x^5/5! - ...
# x: Punkt der Sinusfunktion
# n: Anzahl an Termen der Taylornäherung
    y = x # Output
    fac = 1 # Factorial
    for i in range(1, n):
        n_term = x ** (2 * i + 1)
        fac *= 2 * i * (2 * i + 1)
        sign = (-1) ** i
        y += sign * n_term / fac
    return y

x = 0.5
n = 3 # Länge der Taylorexpansion
sin_x = sinus(x, n)
print(sin_x)

# %%
# Ziel: Berechne die Sinusfunktion mit NumPy
import numpy as np # Importiere das NumPy (Numerisches Python) Paket
x = 0.5
sin_x = np.sin(x)
print(sin_x)

# %% [markdown]
# `NumPy` ist eine der wichtigsten Module für Python und wird in der nächsten Vorlesung ausführlicher vorgestellt.

# %% [markdown]
# # Basics: Was ist ein Programm?
# Ein Programm besteht aus einer Reihe von Anweisungen, die **nacheinander** ausgeführt werden. In einem Programm werden verschiedene Objekte, z.B. Zahlen, Listen oder Text, durch Operationen manipuliert, um ein gewünschtes Ergebnis zu erhalten.
#
# ### Beispiel: Summiere die Zahlen von 1 bis 10

# %%
# Beispiel: Programm
n = 10
my_number = 0
for i in range(1, n + 1):
    my_number = my_number + i

print(my_number)

# %% [markdown]
# Ein Python Programm ist eine **Textdatei**, die üblicherweise mit `.py` endet und Befehle in der Python Sprache enthält. Die Textdatei wird zu einem Python Programm, wenn sie durch einen **Python Intepreter** gelesen wird - üblicherweise durch einen Befehl in der **Kommandozeile**.
#
# `$ python my_script.py`
#
# Alternativ kann ein IDE (Integrated Development Environment) wie **PyCharm** genutzt werden, die sowohl das Programmieren in der Textdatei als auch die Ausführung des Programms in einer Entwicklungsumgebung vereint.
# Zusätzlich bieten Entwicklungsumgebungen nützliche Hilfestellungen, z.B.  durch Syntax-Highlighting und Fehlererkennungen.
# <center>
# <img src="figures/PyCharm_Icon.png" alt="Datenauswertung" width="400"/>
# </center>

# %% [markdown]
# # Einfachheit > Performance
# Die Grundlage des Programmierens ist der Programmcode der von Entwickler*innen geschrieben wird. Guter Code folgt einfachen Prinzipien:
# - **Lesbarkeit** - Ordentlicher Code nutzt **Konventionen** für Variablen, Einrückungen, Kommentare
# - **Verständlichkeit** - Verständlicher Code ist **kommentiert** und **strukturiert**
# - **Konfigurierbarkeit** - Kleine Änderungen an der Aufgabe sollten zu kleinen Änderungen am Code führen
# - **Don't repeat yourself** - Wiederkehrende Aufgaben sollten zusammengefasst und automatisiert werden

# %% [markdown]
# ### Beispiel Lesbarkeit & Verständlichkeit: Fläche eines Kreises
# $A = \pi * r^2$

# %% [markdown]
# <div style="background-color: orange; padding: 10px;">
#     <h2>Bad practice</h2>
# </div>

# %%
# Beispiel: Lesbarkeit
print(f"{3.1415 * (2 ** 2)}")
print(f"{3.1415 * (4 ** 2)}")

# %% [markdown]
# <div style="background-color: lightgreen; padding: 10px;">
#     <h2>Good practice</h2>
# </div>

# %%
# Aufgabe: Berechne die Fläche eines Kreises A = pi * r^2
pi = 3.1415         # Kreiszahl Pi
r_1 = 2             # Radius Kreis 1
r_2 = 4             # Radius Kreis 2
A_1 = pi * (r_1 ** 2) # Fläche Kreis 1
A_2 = pi * (r_2 ** 2) # Fläche Kreis 2
# Textausgabe
print(f"Die Fläche von Kreis 1 beträgt ", A_1)
print(f"Die Fläche von Kreis 2 beträgt ", A_2)

# %% [markdown]
# Das Ergebnis ist zwar das selbe, aber die zweite Version ist **klarer und verständlicher** durch:
# - Kommentare `#` mit kurzen Beschreibungen/Definitionen
# - Sinnvolle Variablennamen
# - Informative Ausgabe der Ergebnisse

# %% [markdown]
# # Übung 0: "Hello World"
# Die `print()` Funktion ist **eine der wichtigsten Funktionen in Python**: Sie  gibt Daten für uns lesbar aus - nützlich zum **debuggen** und um **Ergebnisse** zu erhalten.
# ### Syntax: `print(*Daten_zum_ausgeben*)`

# %%
print("Hello World")

# %% [markdown]
# # Übung 0.5: Wann nutzt man `print()`?
# Oft ist es nicht offensichtlich, wie, wo und welche Daten genau an einer Stelle des Codes gespeichert werden. Die `print()` Funktion kann **Zwischenergebnisse** sichtbar machen.
# ### Aufgabe: Gib das Resultat für "variable3" aus

# %%
# Definiere eine Variable
variable1 = "Hello "
variable2 = "World"
variable3 = 3 * variable1 + variable2
# Unsicher was variable3 enthält? Guck es dir an!

# %% [markdown]
# # Übung 1: Debuggen mit Fehlermeldungen
# Um zu funktonieren, folgen Programmiersprachen festen Regeln. Machen wir bei der Einhaltung der Regeln Fehler, bricht das Programm (hoffentlich) ab! **Python hilft euch Fehler zu finden** durch Fehlermeldungen. Fehlermeldungen beinhalten die folgenden Informationen:
# - In welcher Zeile tritt der Fehler auf?
# - An welcher Stelle tritt der Fehler auf?
# - Was ist das Problem?
# ### Aufgabe: Finde alle Fehler durch die Fehlermeldungen

# %%
pi = 3.1415           # Kreiszahl Pi
r_1 =                 # Radius Kreis 1
r_2 = 4               # Radius Kreis 2
A_1 = pi * (r_1 ** 2) # Fläche Kreis 1
A_2 = pi * (r_2 ** 2) # Fläche Kreis 2
# Textausgabe
print(f"Die Fläche von Kreis 1 beträgt , A_1)
print(f"Die Fläche von Kreis 2 beträgt ", A2)

# %% [markdown]
# ### Google Colab Link
# <img src="figures/qr_code_lecture1.png" alt="Google Colab" width="400"/>
#
# Colab Link: <a href="https://colab.research.google.com/drive/1CqGHfmt7z8T2HMTtNQVOnWrbzN3OBXAr?usp=sharing">https://colab.research.google.com/drive/1CqGHfmt7z8T2HMTtNQVOnWrbzN3OBXAr?usp=sharing</a>

# %% [markdown]
# # Basics: Variablen
# Variablen bilden die Grundlage eines Programms und dienen der **Datenspeicherung**. Eine Variable ist definiert durch drei Dinge:
#
# - **Bezeichner:** Der Name der Variable, z.B. `my_number`
# - **Datentyp:** Die Art der Daten die in der Variable gespeichert werden, bspw. Zahlen, Text, eine Liste von Zahlen oder ein Plot
# - **Wert:** Der spezifische Wert der Variable, bspw. eine spezifische Zahl oder eine Grafik

# %% [markdown]
# Die **Bezeichner** einer Variable können frei gewählt werden, innerhalb der von Python gesetzten Regeln für Variablen:
# - **Python ist case-sensitive:** Groß und Kleinschreibung (`omega`, `Omega`, ...) spielt bei der Bennenung von Variablen eine Rolle
# - **Erlaubte symbole:** `a ... z`,  `0 ... 9` und `_` (**nicht:** `-`)
# - **Geschützte Namen:** Namen von speziellen Funktionen und Befehlen sind geschützt und können nicht überschrieben werden

# %%
# Bezeichner = Wert
my_variable = 3

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px;">
#     <h3>Wichtig</h3>
#     <p>Variablen sollten deskriptiv sein, d.h. der Name einer Variable sollte darauf schließen lassen was sie enthält!</p>
# </div>

# %% [markdown]
# Mehrere Variablen können durch ein Komma `,` getrennt werden, sowohl beim definieren als auch beim ausgeben

# %%
# Definition mehrerer Variablen
number1, number2 = 1, 2
print(number2, number1)

# %% [markdown]
# # Datentypen: Zahlen
#
# Es gibt zwei unterschiedliche Arten von Zahlen: Ganze Zahlen (**integers**) oder Gleitkommazahlen (**floats**).

# %%
# integer (Ganzzahl)
a = 1
b = -5
c = 0
print(a, b, c)

d = 0.1 + 0.2
e = 0.3
f = d - e
print(d, e, f)

# %% [markdown]
# **Floats** können auch in wissenschaftlicher Notation mit einem Exponenten als `1000 = 10e3` und `0.001 = 10e-3` angegeben werden. Während **Integers** in Python eine beliebige Größe haben können sind **Floats** auf Zahlen zwischen $1.7 * 10^{-308}$ bis $1.7 * 10^{308}$ begrenzt, da jede Zahl lediglich 64 Bits speicher zur Verfügung steht.
# Höhere Zahlen sind nicht speicherbar.

# %%
# Overflow
a = 1e307
b = 2e308
print(a, b)

# %% [markdown]
# **Floats** beschreiben nur mit einer begrenzten Genauigkeit das Koninuum der reelen Zahlen, welche als **machine precision** bezeichnet wird.

# %%
a = 0.1 + 0.2
b = 0.3
print(b, f"{b:.20f}")
print(b - a)

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px;">
#     <h3>Wichtig</h3>
#     <p>In Python werden Floats mit einem Punkt <code>.</code> geschrieben, nicht mit einem Komma wie in Deutschland üblich.</p>
# </div>

# %% [markdown]
# # Basics: Operationen mit Zahlen
# Variablen die **Integers** oder **Floats** enthalten, können mit grundlegenden mathematischen Operatoren genutzt werden.

# %% [markdown]
# | **Operation**         | **Symbol** | **Beschreibung**                              |
# |-----------------------|------------|-----------------------------------------------|
# | Addition              | `+`        | Addiert zwei Werte                           |
# | Subtraktion           | `-`        | Subtrahiert den zweiten Wert vom ersten      |
# | Multiplikation        | `*`        | Multipliziert zwei Werte                     |
# | Division              | `/`        | Dividiert den ersten Wert durch den zweiten  |
# | Modulo (Rest)         | `%`        | Gibt den Rest einer Division zurück          |
# | Potenz                | `**`       | Potenziert den ersten Wert mit dem zweiten   |
# | Quadratwurzel         | `** 0.5`   | Zieht die Quadratwurzel des Wertes           |

# %%
a = 2.0
b = 3

# Addition:
add = a + b
# Subtraktion:
sub = a - b
# Multiplikation
mul = a * b
# Division 
div = a / b
# Modulo
mod = a % b
# Exponent 
power = a ** b

print(add, sub, mul, div, mod, power)

# %% [markdown]
# Die Reihenfolge der mathematischen Operationen folgt der Standardreihenfloge mathematischer Operationen (BODMAS): **Klammern, Exponenten, Division, Multiplikation, Addition, Subtraktion** - Kurz gesagt: Punkt vor Strich

# %%
# Klammern vor Exponenten, Exponenten vor Division
a = 9 ** 1 / 2
b = 9 ** (1 / 2)
print(a, b)

# %% [markdown]
# Klammern setzen ist sehr hilfreich um schwer zu entdeckende Fehler zu vermeiden. Sämtliche Klammern müssen allerdings geschlossen sein, da ansonsten ein Fehler produziert wird.

# %% [markdown]
# # Operationen mit Zahlen
# Zusätzlich zu den grundlegenden Operatoren gibt es eine Vielzahl an Funktionen, die auf Zahlen angewandt werden können.

# %% [markdown]
# | **Operation**         | **Symbol** | **Beschreibung**                              |
# |-----------------------|------------|-----------------------------------------------|
# | Absolutwert           | `abs()`    | Gibt den Betrag einer Zahl zurück              |
# | Rundung               | `round()`  | Rundet eine Zahl auf eine bestimmte Dezimalstelle |
# | Maximum               | `max()`    | Gibt den größten Wert aus einer Sequenz zurück |
# | Minimum               | `min()`    | Gibt den kleinsten Wert aus einer Sequenz zurück |

# %%
a = -2.21
b = 3

# Absolutwert
abs_val = abs(a)
# Rundung
round_val = round(a, 1)
# Maximalwert
max_val = max(a, b)
# Minimalwert
min_val = min(a, b)

# Ausgabe
print(abs_val, round_val, max_val, min_val)

# %% [markdown]
# Spezielle mathematische Funktionen, wie bspw. die Exponentialfunktion, werden in Python durch **Module** bereitgestellt.

# %% [markdown]
# # Übung 2: Rechenoperationen

# %% [markdown]
# ### Aufgabe: Verändere den Code, sodass `my_integer` durch die Subtraktion 6 enthält. Lasse dir das Ergebnis mit print() ausgeben.

# %%
my_integer = 9
my_integer - 3
print(my_integer)

# %% [markdown]
# ### Aufgabe: Wende auf `my_integer` eine Addition von 2, Multiplikation mit 3, Subtraktion von 1 und abschließend eine Division durch 2 an.

# %%
my_integer = 9
my_integer = my_integer # Addition
my_integer = my_integer # Multiplikation 
my_integer = my_integer # Subtraktion
my_integer = my_integer # Division
print()

# %% [markdown]
# ### Aufgabe: Finde das Maximum von `Wurzel(3333)` und `33^1.5`

# %%
sqrt = # Wurzel von 3333
expo = # Exponential 33^1.5
max_val = # Find Maximum
# Print out maximum

# %% [markdown]
# ### Aufgabe: Finde mit dem `modulo` Operator heraus ob `7^4` eine gerade Zahl ist

# %%
my_number = 7 # 7^4
mod = my_number #

######################
# Nicht verändern
######################
if mod != 0:
    print(f"{my_number} ist eine ungerade Zahl")
else:
    print(print(f"{my_number} ist eine gerade Zahl")

# %% [markdown]
# # Datentypen: Strings
# Text, oder **Strings**, wird in Python durch Anführungszeichen `''` oder `""` markiert, um von **Variablen** unterschieden zu werden.

# %%
my_text = "Hello World"
print(my_text)

# %% [markdown]
# Strings können als Abfolge einzelner Zeichen, **Characters** betrachtet werden, die also genau wie bei Listen  mittels eckiger Klammern separat aufgerufen werden können.

# %%
my_text = "Hello World"
print(my_text[0], my_text[1], my_text[2], my_text[3], my_text[4])

# %% [markdown]
# **Strings** sind ein fundamental anderer Datentyp als **Floats** und **Integers** und können nur in Ausnahmefällen kombiniert werden.

# %%
my_text = "10"
my_int = 2
print(my_text + my_int)

# %% [markdown]
# **Strings** die Zahlen enthalten müssen erst in Floats oder Integers umgewandelt werden bevor sie als solche genutzt werden können.

# %%
my_text = "10.1"
my_int = 2
my_text = float(my_text)
print(my_text + my_int)

# %% [markdown]
# Strings können mit einer Vielzahl an Operationen manipuliert werden

# %% [markdown]
# | **Operation**                 | **Beschreibung**                                | **Beispiel**                                         | **Ausgabe**                |
# |-------------------------------|-------------------------------------------------|------------------------------------------------------|----------------------------|
# | Verkettung | Verbindet Strings mit `+`                       | `"Hallo, " + "Welt"`                                 | `Hallo, Welt`              |
# | Länge bestimmen               | Anzahl der Zeichen mit `len()`                  | `len("Python")`                                      | `6`                        |
# | Ersetzen                      | Ersetzt Substrings mit `replace()`              | `"Ich liebe Python".replace("Python", "Coding")`     | `Ich liebe Coding`         |
# | Aufteilen                     | Teilt String in eine Liste von Wörtern                    | `"eins zwei drei".split()`                           | `['eins', 'zwei', 'drei']` |

# %% [markdown]
# Variablen können in Text mittels der `format()` Funktion oder als `f""` **String** eingefügt werden.

# %%
# Gibt eine berechnete Konzentration aus
concentration = 0.2   # mol / l
# f"" string method
print(f"Die finale Konzentration beträgt {concentration} mol / l")
# format function
print("Die finale Konzentration beträgt {} mol / l".format(concentration))

# %% [markdown]
# # Datentypen: Container
# Variablen können zusammengefasst werden in Containern, die Operationen auf Gruppen von Daten erlauben. Es gibt 4 verschiedene grundlegende Arten von Containern:
#
# - **Listen `[]`:** Listen enthalten geordnete Daten, die überschrieben werden können
# - **Tupel `()`:** Tupels enthalten geordnete Daten, die **nicht** überschrieben werden können
# - **Sets: `{}`** Sets enthalten **ungeordnete, einzigartige** Daten
# - **Dictionaries `{}`:** Dictionaries enthalten ungeordnete Key-Value Paare, bei denen jedem Key ein Objekt zugeordnet ist
#
# Für den Moment konzentrieren wir uns auf **Listen**. Eine **Liste** enthält eine Menge an einzelnen Elementen (**Integers**, **Floats**, **Strings**, **Bools**), die an einer bestimmten Position, einem Index, gespeichert sind. Der Index zählt die Elemente in der Liste, beginnend bei 0. Auf einzelne Elemente der Liste kann über den Index zugegriffen werden mittels eckiger Klammern `liste[index]`. Wenn versucht wird auf ein Element zuzugreifen, dass nicht in dem Container enthalten ist, wird ein Fehler produziert. Auf mehrere Elemente kann durch **Slicing** `list[index1:index2]` zugegriffen werden, wodurch alle Elemente zwischen den Indices ausgegeben werden.

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px;">
#     <h3>Wichtig</h3>
#     <p>
#        In Python wird immer ab 0 gezählt.
#     </p>
# </div>

# %%
# Listen Basics
elements = ["Hydrogen", "Helium", "Lithium", "Berrylium", "Boron", "Carbon", "Nitrogen"]
print(elements[0], elements[-1])
print(elements[0:4])

# %% [markdown]
# <center>
# <img src="figures/list_elements.png" alt="" width="1000"/>
# </center>
#
# Quelle: [Hier](https://pythoninchemistry.org/intro_python_chemists/basics/collections.html)

# %% [markdown]
# # Listen erzeugen
#
# ### Eine leere Liste

# %%
list1 = list()
# Oder
list2 = []
print(list1, list2)
# Out:
# [] []

# %% [markdown]
# ### Eine Liste mit Elementen

# %%
int_list = [1, 2, 3, 4]
float_list = [1.1, 2.2, 3.3, 4.4]
string_list = ["a", "b", "c", "d"]
# Nicht empfohlen: Gemischte Listen
mixed_list = [1, "b", 3.3, ["Nested List"]]
print(mixed_list)
# Out:
# [1, 'b', 3.3, ['Nested List']]

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px;">
#     <h3>Wichtig</h3>
#     <p>
#        Listen mit verschiedenen Datentypen zu füllen führt oft zu Problemen!
#     </p>
# </div>

# %% [markdown]
# ### Listen erweitern

# %%
list1 = []
# .append()
list1.append("a")
print(list1)
# Add elements
list1 = list1 + ["b"]
print(list1)
# Out:
# ['a']
# ['a', 'b']

# %% [markdown]
# # Listen: Operationen
# **Listen** können mit einer Vielzahl an Funktionen manipuliert werden.

# %% [markdown]
# | **Operation**         | **Beschreibung**                                  | **Syntax**                     |
# |-----------------------|---------------------------------------------------|--------------------------------|
# | Hinzufügen             | Fügt ein Element am Ende der Liste hinzu         | `liste.append(element)`        |
# | Einfügen              | Fügt ein Element an einem bestimmten Index ein    | `liste.insert(index, element)` |
# | Löschen               | Löscht das Element am angegebenen Index          | `del liste[index]`            |
# | Länge bestimmen       | Gibt die Anzahl der Elemente in der Liste zurück   | `len(liste)`                  |
# | Sortieren             | Sortiert die Liste in aufsteigender Reihenfolge   | `liste.sort()`                       |
# | Zählen                | Zählt, wie oft ein Element in der Liste vorkommt   | `liste.count(element)`         |
# | Finden                | Gibt den Index des ersten Vorkommens eines Elements | `liste.index(element)`         |

# %%
elements = ["Hydrogen", "Helium", "Lithium", "Berrylium", "Boron", "Carbon", "Nitrogen"]
elements.append("Oxygen")
print(elements)
elements.index("Carbon")

# %% [markdown]
# **Listen** sind keine Vektoren und sind, genau wie **Strings**, im Allgemeinen nicht kompatibel mit mathematischen Operatoren.

# %%
my_list = [1, 2, 3, 4]
my_list = my_list * my_list
print(my_list)

# %% [markdown]
# # Übung 3: Operationen mit Listen und Strings
# ### Aufgabe: Berechne die molare Masse von Glucose mithilfe der Liste der molaren Massen und des Strings der Summenformel.

# %%
my_list = [12, 1, 16]   # molare Massen: C, H, O 
my_string = "C6H12O6"   # Glucose

kohlenstoff = int(my_string[1]) * my_list[0]                
wasserstoff = 
sauerstoff =            
mol_mass = # Addiere die einzelnen Massen   
print(f"Die molare Masse von Glucose beträgt {mol_mass} g/mol.") # Wende den f""-String an um die molare Masse ausgeben zu lassen.

# %% [markdown]
# ### Aufgabe: Berechne die Konzentration aller Stoffe
# Hinweise:
# - Durch Slicing kann man sich bspw. mit `list[::2]` jeden zweiten Wert einer Liste ausgeben lassen
# - Strings können durch die `.split()` Funktion in Listen überführt werden
# - In einer Liste können `strings` durch die `map` Funktion in `floats` oder `integers` umgewandelt werden: `list(map(int, my_list))` oder `list(map(float, my_list))`

# %%
# Struktur: Stoff, Masse [g], Molmasse [g/mol], Volumen Lsgmittel [mL]
c_string = "C6H6, 1, 78, 100, C2H4O2, 0.8, 60, 95, C5H5N, 1.1, 79, 110"
c_list = c_string.split(",")

mol = c_list[::4]
mass = c_list[1::4]
mass = list(map(float, mass))
mol_mass = c_list[2::4]
mol_mass = list(map(float, mol_mass))
vol = c_list[3::4]
vol = list(map(float, vol))

c1 = (mass[0] / mol_mass[0]) / vol[0] * 1000
c2 = (mass[1] / mol_mass[1]) / vol[1] * 1000
c3 = (mass[2] / mol_mass[2]) / vol[2] * 1000

print(f"Die Konzentration von {mol[0]} beträgt {c1} mol/L.")
print(f"Die Konzentration von {mol[1]} beträgt {c2} mol/L.")
print(f"Die Konzentration von {mol[2]} beträgt {c3} mol/L.")

# %% [markdown]
# # Datentypen: Bool Werte
# **Bool**'sche Werte können nur zwei Werte annehmen: Wahr oder Falsch, bzw. in Python `True` und `False`. Sie spielen eine wichtige Rolle in der Strukturierung von Programmen, bspw. indem gewisse Operationen nur durchgeführt werden wenn ein Wert `True` ist.

# %% [markdown]
# Oft werden **Bool**'sche Werte durch **Vergleichsoperatoren** oder **logische Operationen** erzeugt. **Vergleichsoperatoren** testen eine Bedingung zwischen zwei einzelnen Datenobjekten, bspw. zwischen zwei Zahlen oder zwei **Strings**, und geben einen **Bool**'schen Wert zurück.

# %%
# Vergleichsoperatoren
a = 1 
b = 2

# Kleiner
lower = a < b
# Größer
greater = a > b 
# Gleich
eq = a == b
# Ungleich
neq = a != b
# Größer Gleich
greatereq = a >= b
# Kleiner Gleich
lowereq = a <= b

print(lower, greater, eq, neq, greatereq, lowereq)

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px;">
#     <h3>Wichtig</h3>
#     <p>
#        Vergleiche zwischen <code>Floats</code> sind oft schwierig, da durch die begrenzte Maschinenpräzision zwei Floats selten exakt gleich sind!
#     </p>
# </div>

# %%
a = 0.1 + 0.2
b = 0.3
eq = a == b

print(eq)

# %% [markdown]
# # Logische Operatoren
#
# <center>
#  <img src="figures/logical_gates.webp" alt="" width="1600"/>
# </center>

# %% [markdown]
# # Logische Operatoren

# %% [markdown]
# **Logische operatoren** kombinieren zwei **Bool**sche Werte und geben gemäß ihrer Logik eine neue **Bool** zurück.
# | **Operator** | **Beschreibung**                                  | **Beispiel**                      | **Ergebnis**      |
# |--------------|---------------------------------------------------|-----------------------------------|-------------------|
# | `and`        | Gibt `True` zurück, wenn beide Operanden `True` sind. | `True and True`                   | `True`            |
# |              |                                                   | `True and False`                  | `False`           |
# | `or`         | Gibt `True` zurück, wenn mindestens einer der Operanden `True` ist. | `True or False`                   | `True`            |
# |              |                                                   | `False or False`                 | `False`           |
# | `not`        | Negiert den Booleschen Wert des Operanden.       | `not True`                        | `False`           |
# |              |                                                   | `not False`                       | `True`            |

# %%
# Logische Operatoren
a = True
b = False
# Und
und = a and b
# Oder
oder = a or b
# XOR
entweder_oder = a ^ b
# Nicht
nicht = not a

print(und, oder, entweder_oder, nicht)

# %% [markdown]
# **Bool**'sche Werte können für mathematische Operationen genutzt werden, wobei sie entweder die Werte `True = 1` oder `False = 0` annehmen.

# %%
a = True 
b = 2.7
mult = a * b
add = a + b
div = a / b

print(mult, add, div)

# %% [markdown]
# Umgekehrt können logische Operationen zwischen sämtlichen Objekten durchgeführt werden. Dabei sind sämtliche einzelnen Datenobjekte `True`. Die einzige Ausnahme bildet die **Integer** `0`, die `False` ist. Variablen, die zwar deklariert wurden aber keinen Wert haben, bspw. ein leerer **String** `""`, sind ebenfalls `False`.

# %%
a = "Apfel"
b = 0

und = a and b
oder = a or b
nicht = not a

print(und, oder, nicht)

# %% [markdown]
# # Übung 4: Logische Operationen
# ### Aufgabe: Wende logische Operatoren sowie Vergleichsoperatoren an um mit den Variablen einen sinnvollen Output aus den gegebenen Beispielen zu erzeugen.

# %%
# Beispiel: 
Vorlesungsbeginn = 7.5 # Uhrzeit
Wecker_klingelt = 8.0
# Logische Schlussfolgerung:
print("Schaffe ich es zur Vorlesung?", Wecker_klingelt < Vorlesungsbeginn)

Siedepkt_Wasser = 100 
Temperatur1 = 80
print(f"Damit es siedet muss Wasser der Temperatur {Temperatur1} °C weiter erhitzt werden:", )

Masse_Glucose = 180
Masse_Ribose = 150
print("Glucose ist ein Isomer von Ribose:", )

Hitze = True
Katalysator = False
print("H2O2 zersetzt sich:", ) 

Kittel = True
Schutzbrille = False
print("Studierende/r darf das Labor betreten:", )

Glasgerät_dreckig = True
print("Das Glasgerät kann verwendet werden:", )

# %% [markdown]
# # If/Else statements: Entscheidungen
# <center>
# <img src="figures/decisions.svg" alt="Google Colab" width="1600"/>
# </center>
#
# Quelle: [Hier](https://www.codechef.com/blogs/if-else-conditions-in-python)

# %% [markdown]
# # If/Else statements: Entscheidungen
# In Python gibt es Entscheidungsstrukturen, sogenannte **If/Else** Blöcke. Sie folgen der Syntax `if Bedingung: ... else: ...`. Dabei wird der erste Code Block ausgeführt wenn die Bedingung erfüllt ist, während der andere ausgeführt wird wenn sie **nicht** erfüllt ist. Die Code-Blöcke durch ihre Einrückung voneinander getrennt.

# %%
# If-else
color = "rot"

if color == "rot":
    print("Lithium!")
else:
    print("Natrium!")

# %% [markdown]
# <center>
# <img src="figures/decision_flame.png" alt="Google Colab" width="800"/>
# </center>

# %% [markdown]
# # If - Elif - Else
# Eine Bedingung kann durch einen **Bool** Wert ersetzt werden oder mehrere Bedingungen verknüpfen gemäß der **Bool** Logik. Mehrere Spezialfälle können mit durch das **elif** Keyword hinzugefügt werden.

# %%
# If-elif-else
color = "blau"

if color == "rot":
    print("Lithium!")
elif color == "gelb":
    print("Natrium!")
else: 
    print("Kalium!")

# %% [markdown]
# <center>
# <img src="figures/decision_flame2.png" alt="Google Colab" width="800"/>
# </center>

# %% [markdown]
# # Kontrollstrukturen
# <center>
# <img src="figures/control_flow.webp" alt="Google Colab" width="1600"/>
# </center>
#
# Quelle: [Hier](https://dotnettutorials.net/lesson/control-flow-statements-in-python/)

# %% [markdown]
# # Kontrollstrukturen: Iterieren & Loops
# Anstatt einzeln auf die Elemente einer Liste zuzugreifen, kann eine Operation nacheinander auf alle Elemente einer Liste angewandt werden in einem sogenannten `for` loop. Dabei wird die Liste Index für Index durchgegangen (**iteriert**), bis alle Elemente einmal behandelt wurden. Der Loop wird eingeleitet durch das **Keyword** `for ... in` und folgt der allgemeinen Syntax `for [name] in [iterable]:`

# %%
my_list = [5, 3, 6, 2]
for element in my_list:
    print(element)

# %% [markdown]
# <center>
# <img src="figures/flowchart_for.png" alt="Google Colab" width="600"/>
# </center>
#
#
# Quelle: [Hier](https://pythoninchemistry.org/intro_python_chemists/basics/loops.html)

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px;">
#     <h3>Wichtig</h3>
#     <p>
#     Ein <strong>For-Loop</strong> ist eine Kontrollstruktur, innerhalb derer der darauffolgende Code nach bestimmten Regeln ausgeführt wird. Der Geltungsbereich aller Kontrollstrukturen, also auch von For-Loops, wird bestimmt durch die <strong>Einrückung</strong> (Intendation), die üblicherweise 4 Leerzeichen beträgt.     </p>
# </div>

# %% [markdown]
# # For-Loops
# | **Loop**         | **Funktion**                                  | **Syntax**                     |
# |-----------------------|---------------------------------------------------|--------------------------------|
# | Liste             | Loop über Elemente einer einzelne Liste         | `for el in list:`        |
# | Zahlen              | Loop über Zahlen von `start` bis `end`    | `for element in range(start, end):` |
# | mehrere Listen               | Loop über die Elemente mehrerer Listen          | `for el1, el2, ... in zip(list1, list2, ...):`            |
# | Index und Liste       | Loop über den Index und die Elemente einer Liste   | `for idx, el in enumerate(list):`                  |
#
#
# Ein For-Loop muss nicht direkt über die Elemente einer Liste iterieren. Oft ist es leichter, über Zahlen, bspw. die Indices einer Liste, zu loopen. Dies wird mit der `range()` Funktion erreicht.

# %%
my_list = [5, 3, 6, 2]
n = len(my_list)

for i in range(n):
    my_list[i] = my_list[i] + 1

print(my_list)

# %% [markdown]
# Der Code innerhalb einer Kontrollstruktur kann beliebig lang und komplex sein, und es ist auch möglich (und häufig) mehrere Loops ineinander zu schachteln.

# %% [markdown]
# Eine kompaktische und praktische Methode um kurze Operationen auf Listen auszuführen sind **List Comprehensions**. Diese folgen einer einfachen einzeiligen Syntax:

# %%
squares = [x ** 2 for x in range(10)]
print(squares)

# %% [markdown]
# # Übung 5: For-loops
# ### Aufgabe: Rechne die Temperaturen in der Liste mithilfe eines for-loop in °C um.

# %%
temperaturen = [235, 342, 600, 273] # Temperaturen in Kelvin

for :

print(temperaturen)

# %% [markdown]
# ### Aufgabe: Rechne die Temperaturen in der Liste mithilfe einer List comprehension in °C um.

# %%
temperaturen = [235, 342, 600, 273] # Temperaturen in Kelvin

temperaturen = # List comprehension

print(temperaturen)

# %% [markdown]
# ### Aufgabe: Entferne alle Elemente der Liste die fehlerhaft sind
# Hinweise:
# - Nutze `if/else` statements
# - Mit List comprehension kann die Aufgabe in zwei Zeilen gelöst werden

# %%
wavenumber = [1000, 1010, 1020, 1030, 1040, 1050, 1060, 1070, 1080, 1090, 1100, 1110, 1120, 1130, 1140, 1150, 1160, 1170, 1180, 1190, 1200]
intensity = [0.000, False, 0.045, 0.052, 0.030, 0.020, False, 0.75, 0.082, 0.083, 0.069, 0.038, 0.010, 0.004, 0.030, 0.077, 0.091, 0.059, 0.090, 0.072, False]

# %% [markdown]
# # Loops über mehrere Variablen
# Anstatt nur eine einzelne Variable in einem **For-Loop** zu nutzen, können mit der `zip` Funktion auch mehrere Variablen in einem einzelnen Loop genutzt werden wenn sie die gleiche Länge haben.

# %%
molecules = ["Mol1", "Mol2", "Mol3"]
weights = [109.3, 165.9, 93.5]
for mol, w in zip(molecules, weights):
    print(f"{mol} wiegt {w} g / mol")

# %% [markdown]
# Um gleichzeitig über den Index und ein Element aus einem iterierbaren Objekt zu loopen, kann die `enumerate()` Funktion genutzt werden.

# %%
molecules = ["Mol1", "Mol2", "Mol3"]
weights = [109.3, 165.9, 93.5]
for i, mol in enumerate(molecules):
    w = weights[i]
    print(f"{i}. {mol} wiegt {w} g / mol")

# %% [markdown]
# # Übung 6: Loops über mehrere Variablen und if-else statements
# ### Aufgabe: Es sind in der Liste "temperaturen" fünf Schmelzpunkte für verschiedene Elemente in "stoffe" gelistet. Die Listen sind bereits sortiert, sodass z.B. der erste Schmelzpunkt zum ersten Element in "stoffe" gehört. Lass mithilfe einer loop für die Einträge der Liste den **Schmelzpunkt** mit dem jeweiligen **Element** als **Aufzählung** ausgeben. Also beispielhaft nach dem Schema:
#
# **1.** Der Schmelzpunkt von **Wasserstoff** liegt bei **-259 °C**.
#
# **2.** Der ...
#
# Einer der Werte ist allerdings unphysikalisch und sollte zuvor mithilfe einer List comprehension entfernt werden.

# %%
temperaturen = [14, 303, -10, 505, 337] # Schmelzpunkte in Kelvin
stoffe = ["Wasserstoff", "Gallium", "Helium", "Zinn", "Kalium"] # zugehörige Stoffe
temp_masked =  # auszufüllen
stoffe_masked =  # auszufüllen

for in :
    
    print(f"")

# %% [markdown]
# ### Aufgabe: Entferne alle unnötigen Wiederholungen und gib nur den Stoff mit der höchsten Konzentration aus.
# Hinweise:
# - Nutze "List comprehension" anstelle von `map` Funktionen
# - Mit `zip()` kann man über mehrere Listen gleichzeitig loopen

# %%
# Struktur: Stoff, Masse [g], Molmasse [g/mol], Volumen Lsgmittel [mL]
c_string = "C6H6, 1, 78, 100, C2H4O2, 0.8, 60, 95, C5H5N, 1.1, 79, 110"
c_list = c_string.split(",")

mol = c_list[::4]
mass = [float(el) for el in c_list[1::4]]
mol_mass = [float(el) for el in c_list[2::4]]
vol = [float(el) for el in c_list[3::4]]

c = [(mass[i] / mol_mass[i]) / vol[i] for i in range(len(vol))] # List comprehension
c_max = max(c)
for m, ci in zip(mol, c):
    if ci == c_max:
        print(f"Die Konzentration von {m} beträgt {ci} mol/L und ist am höchsten!")

# %% [markdown]
# ### Aufgabe: Finde den Punkt mit maximaler Intensität im Spektrum

# %%
wavenumber = [1000, 1010, 1020, 1030, 1040, 1050, 1060, 1070, 1080, 1090, 1100, 1110, 1120, 1130, 1140, 1150, 1160, 1170, 1180, 1190, 1200]
intensity = [0.000, 0.034, 0.045, 0.052, 0.030, 0.020, 0.61, 0.75, 0.082, 0.083, 0.069, 0.038, 0.010, 0.004, 0.030, 0.077, 0.091, 0.059, 0.090, 0.072, 0.041]
# Finde das maximum!

print("Die maximale Intensität von {} wird bei einer Wellenzahl von {} erreicht")
